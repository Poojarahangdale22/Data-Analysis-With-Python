# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojarahangdale22/Data-Analysis-With-Python/blob/main/Californiahousinganalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ** California Housing Analysis **
#
# In this data analysis project, we will explore the California Housing Dataset, a widely-used dataset in the field of data analysis. This dataset is of significant interest to researchers, policymakers, and real estate professionals as it provides valuable insights into the housing market in various regions of California.
#
#
# ![xyz.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd


# for Loading the housing dataset from Excel

housing_data = pd.read_excel('housing+(1).xlsx')

# Displaying the first few rows of the dataset to verify the data was loaded correctly
print(housing_data.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
housing_data.shape
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Let's categorize the features in our dataset into nominal, ordinal, discrete, or continuous:
#
# 1. **Nominal Features:**
#    - `ocean_proximity` is a nominal feature. It represents categories such as "NEAR BAY","Island","NearOCean" without a meaningful order.
#
# 2. **Ordinal Features:**
#    - None of the features in our dataset appear to be ordinal.But in last question we categorise the house large ,medium, small it is ordinal.Which has meaningful order on the basis of number of rooms.
#
# 3. **Discrete Features:**
#    - `housing_median_age` is a discrete feature. It represents the age of houses, which is likely measured in whole years.
#    - `total_rooms`, `total_bedrooms`, `population`, `households` are also discrete features. They represent counts of rooms, bedrooms, individuals, and households, respectively.
#
# 4. **Continuous Features:**
#    - `longitude`, `latitude` are continuous features. They represent geographical coordinates and can take on a wide range of values.
#    - `median_income` is a continuous feature. It represents the median income, which can take on a wide range of numeric values.
#    - `median_house_value` is a continuous feature. It represents the median house value, which is a numeric variable with a wide range.

# %%
housing_data["ocean_proximity"].value_counts() #distribution of value within a oceanproximity colunm
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing_data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing_data.hist(bins=50,figsize=(20,50))  #
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# In this we can see that there is some outliers in median house value.

# %% [markdown]
# ## 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the housing dataset from Excel

housing_data = pd.read_excel('housing+(1).xlsx')

# Display the first few rows of the dataset to verify the data was loaded correctly
print(housing_data.head())


median_income_1 = 'median_income'

# Calculate the average median income
average_median_income = housing_data[median_income_1].mean()


# Plot a histogram to visualize the distribution of median income

plt.figure(figsize=(8, 6))
plt.hist(housing_data[median_income_1], bins=30, edgecolor='k')
plt.title("Median Income Distribution")
plt.xlabel("Median Income")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()



# Print the average median income
print("Average Median Income:", average_median_income)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY
# Average Median Income: 3.8706710029069766

# %% [markdown]
# **Histogram:**
#
# The histogram represents the frequency or count of observations within specified intervals  of the median income values.
# In the x-axis, you have the ranges of median income values , and on the y-axis, you have the frequency or count of occurrences in each bin.
#
#
#
# Now, regarding the average median income:
#
# - The calculated average median income is approximately 3.87. This value pertains to the `median_income` feature, which is continuous and represents the median income of households in the dataset.

# %% [markdown]
# ## 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observation.

# %%
import matplotlib.pyplot as plt

# Assuming you have loaded your housing dataset into a variable called 'housing_data'

# Extract the 'housing_median_age' column
housing_median_age = housing_data['housing_median_age']

# Plot a histogram to visualize the distribution
plt.figure(figsize=(8, 6))
plt.hist(housing_median_age, bins=30, edgecolor='k')
plt.title("Distribution of Housing Median Age")
plt.xlabel("Housing Median Age")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Show with the help of visualization, how median_income and median_house_values are related

# %%
import matplotlib.pyplot as plt



median_income = housing_data['median_income']

median_house_value = housing_data['median_house_value']

#  for Creating a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(median_income, median_house_value, alpha=0.5)
plt.title("Relationship between Median Income and Median House Value")
plt.xlabel("Median Income")
plt.ylabel("Median House Value")
plt.grid(True)
plt.show()

# %% [markdown]
# In ths plot ,we can see that median income and median housevalue is directly proprtional to each other.

# %% [markdown]
# # 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
# Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.
import pandas as pd


# Create a new dataset with rows where 'total_bedrooms' is not NaN
cleaned_housing_data = housing_data.dropna(subset=['total_bedrooms'])

# Optionally, you can reset the index of the new dataset
cleaned_housing_data.reset_index(drop=True, inplace=True)

# Now 'cleaned_housing_data' contains only the rows where 'total_bedrooms' is available

print(cleaned_housing_data.head())
cleaned_housing_data.shape
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY
# (20433, 10)

# %% [markdown]
# ## 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set

# %%
import pandas as pd

# Assuming you have loaded your housing dataset into a variable called 'housing_data'

# Calculate the mean value of 'total_bedrooms' from the original dataset
mean_total_bedrooms = housing_data['total_bedrooms'].mean()

# Create a new dataset with missing values in 'total_bedrooms' filled with the mean
filled_housing_data = housing_data.fillna({'total_bedrooms': mean_total_bedrooms})

# Now 'filled_housing_data' contains the original data with missing 'total_bedrooms' values filled with the mean
print(filled_housing_data.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %% [markdown]
# ## 7. Plot latitude versus longitude and explain your observations.

# %%
import matplotlib.pyplot as plt

# Assuming you have loaded your housing dataset into a variable called 'housing_data'

# Extract latitude and longitude columns
latitude = housing_data['latitude']
longitude = housing_data['longitude']

# Create a scatter plot
import pandas as pd
import matplotlib.pyplot as plt
housing_data.plot(kind="scatter",x="longitude",y="latitude",alpha=0.1,s=housing_data["population"]/100,label="population",c="median_house_value",cmap=plt.get_cmap("jet"))
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# In this plot we can clearly see that longitude and lattitude is inversly proprtional to each other.And here it is shwing that due to population median housle value increases.

# %% [markdown]
# # 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
import pandas as pd

# Assuming you have loaded your housing dataset into a variable called 'housing_data'

# Create a new dataset where 'ocean_proximity' is 'Near Ocean'
near_ocean_data = housing_data[housing_data['ocean_proximity'] == 'Near Ocean']

# Optionally, you can reset the index of the new dataset
near_ocean_data.reset_index(drop=True, inplace=True)

# Now 'near_ocean_data' contains only the rows where 'ocean_proximity' is 'Near Ocean'
print(near_ocean_data.head())
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %% [markdown]
# # 9. Find the mean and median of the median income for the data set created in question 8.

# %%
import pandas as pd

# Assuming you have created the 'near_ocean_data' dataset as mentioned in question 8

# Extract the 'median_income' column from the 'near_ocean_data' dataset
median_income_near_ocean = near_ocean_data['median_income']


# Calculate the mean and median of the 'median_income' column
mean_median_income = median_income_near_ocean.mean()
median_median_income = median_income_near_ocean.median()

# Print the results
print("Mean Median Income:", mean_median_income)
print("Median Median Income:", median_median_income)

# %% [markdown]
# ## 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
import pandas as pd



# Define a custom function to categorize bedroom sizes

def categorize_bedroom_size(total_bedrooms):
    if total_bedrooms <= 10:
        return 'Small'
    elif 10 < total_bedrooms < 1000:
        return 'Medium'
    else:
        return 'Large'

# Apply the custom function to create the 'total_bedroom_size' column
housing_data['total_bedroom_size'] = housing_data['total_bedrooms'].apply(categorize_bedroom_size)

# Display the updated dataset with the new column
print(housing_data.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY
#
#   total_bedroom_size
# 0             Medium
# 1              Large
# ...

# %%
 corr_matrix = housing_data.corr()
 corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# <ipython-input-7-90507a8716ae>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=housing_data.corr()
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %% [markdown]
# In this corelation we can see that  median_house_value is highly corelated to median income.Where rich people live then the houses is more expensive.

# %%
dummies=pd.get_dummies(cleaned_housing_data.ocean_proximity)
housing_na_dummies=pd.concat([cleaned_housing_data,dummies],axis='columns')
housing_na_dummies.head()
housing_clean=housing_na_dummies.drop(['ocean_proximity','ISLAND'],axis='columns')
housing_clean.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value  <1H OCEAN  \
# 0         322         126         8.3252              452600          0
# 1        2401        1138         8.3014              358500          0
# 2         496         177         7.2574              352100          0
# 3         558         219         5.6431              341300          0
# 4         565         259         3.8462              342200          0
#
#    INLAND  NEAR BAY  NEAR OCEAN
# 0       0         1           0
# 1       0         1           0
# ...

# %%
X=housing_clean.drop(columns=['median_house_value'])
X.head()
y=housing_clean['median_house_value']
y.head()
# Out:
# 0    452600
# 1    358500
# 2    352100
# 3    341300
# 4    342200
# Name: median_house_value, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1984)

# %%
from sklearn.linear_model import LinearRegression
OLS = LinearRegression()


OLS.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# display the intercept and coefficient of the OLS model
print("Intercept is"+ str(OLS.intercept_))
print (" THe set Of coeffiecient are"+ str(OLS.coef_))
print("THe R-squared Value is"+str(OLS.score(X_train,y_train)))
# Out:
# Intercept is-2146719.4958721935
#  THe set Of coeffiecient are[-2.72191872e+04 -2.61224400e+04  1.03631750e+03 -6.39771322e+00
#   9.97707401e+01 -3.73545857e+01  4.99035484e+01  3.93656164e+04
#  -1.49036788e+05 -1.87787533e+05 -1.51883617e+05 -1.45673607e+05]
# THe R-squared Value is0.6433902949192565

# %%
# predicting with OLS
y_pred = OLS.predict(X_test)
performance = pd.DataFrame({'PREDICTIONS':y_pred,'ACTUAL VALUES':y_test})
performance['error']=performance['ACTUAL VALUES']-performance['PREDICTIONS']
performance.head()
# Out:
#          PREDICTIONS  ACTUAL VALUES         error
# 15027  315646.738470         328200  12553.261530
# 15275  235926.156196         156900 -79026.156196
# 16054  157003.325611          87200 -69803.325611
# 15208  172404.340246         141000 -31404.340246
# 1888    82931.270634         100800  17868.729366

# %%
# preparing data for plotting

performance.reset_index(drop=True,inplace=True)
performance.reset_index(inplace=True)
performance.head()
# Out:
#    index    PREDICTIONS  ACTUAL VALUES         error
# 0      0  315646.738470         328200  12553.261530
# 1      1  235926.156196         156900 -79026.156196
# 2      2  157003.325611          87200 -69803.325611
# 3      3  172404.340246         141000 -31404.340246
# 4      4   82931.270634         100800  17868.729366

# %%
# plot the residuals

fig = plt.figure(figsize=(10,5))
plt.bar('index','error',data=performance[:50],color='blue',width=0.3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot the residuals
import statsmodels.api as sm
X_train=sm.add_constant(X_train)
nicerOLS=sm.OLS(y_train,X_train).fit()
nicerOLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     median_house_value   R-squared:                       0.643
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     2456.
# Date:                Mon, 02 Oct 2023   Prob (F-statistic):               0.00
# Time:                        14:27:12   Log-Likelihood:            -2.0522e+05
# No. Observations:               16346   AIC:                         4.105e+05
# Df Residuals:                   16333   BIC:                         4.106e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...
